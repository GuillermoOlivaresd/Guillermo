# %%
Type (3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_81/572604313.py in <module>
# ----> 1 Type (3)
#
# NameError: name 'Type' is not defined

# %%
type (3)
# Out:
# int

# %%
type (3/5)
# Out:
# float

# %%
x ='nombre1'

# %%
import numpy as np

# %%
type(x)
# Out:
# str

# %%
import math

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type (true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_81/1462424904.py in <module>
# ----> 1 type (true)
#
# NameError: name 'true' is not defined

# %%
type (True)
# Out:
# bool

# %%
type (None)
# Out:
# NoneType

# %%
## listas

# %%
lista = [1, 3/5, 'nombre', math.pi, True, 5<=3, 1==3, 3==3]

# %%
print (lista)
# Out:
# [1, 0.6, 'nombre', 3.141592653589793, True, False, False, True]

# %%
listastr= ['zeroth','first', 'second', 'third', 'fourth','fifth','sixth']
listastr
# Out:
# ['zeroth', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
listastr.sort()
listastr
# Out:
# ['0', 'fifth', 'first', 'fourth', 'second', 'sixth', 'third']

# %%
listastr
# Out:
# ['0', 'fifth', 'first', 'fourth', 'second', 'sixth', 'third']

# %%
listastr
# Out:
# ['0', 'fifth', 'first', 'fourth', 'second', 'sixth', 'third']

# %%
numbers=[1,2,3,4,5,6]

# %%
listastr
# Out:
# ['zeroth', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
numbers[5]
# Out:
# 6

# %%
numbers[:3]
# Out:
# [1, 2, 3]

# %%
numbers[-3:]
# Out:
# [4, 5, 6]

# %%
numbers[1:3]
# Out:
# [2, 3]

# %%
x = sum(numbers)
x
# Out:
# 21

# %%
y= len(numbers)

# %%
promedio = x/y

# %%
promedio
# Out:
# 3.5

# %%
## UNA FOR LOOOP

# %%
numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
for i in numbers:
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in lista:
    print (i, '\t\t', type (i))
# Out:
# 1 		 <class 'int'>
# 0.6 		 <class 'float'>
# nombre 		 <class 'str'>
# 3.141592653589793 		 <class 'float'>
# True 		 <class 'bool'>
# False 		 <class 'bool'>
# False 		 <class 'bool'>
# True 		 <class 'bool'>

# %%
x = 6
y = 1
if x < y:
    print (x,'<',y)
else:
    print(x,'>',y)
# Out:
# 6 > 1

# %%
x = 6
y = 1
if x < y:
    print ('{} < {}'.format(x,y))
else:
    print('{} > {}'.format(x,y))
# Out:
# 6 > 1
