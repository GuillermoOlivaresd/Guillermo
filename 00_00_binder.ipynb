# %% [markdown]
# # Páginas para programar python

# %%
# Out:
# UsageError: Line magic function `%lsdatasets` not found.

# %%
import pandas as pd
import seaborn as sns

# %%
import numpy as np

# %%
import matplotlib.pyplot as pl

# %%
df = pd.read_csv("COVID-19 Survey Student Responses.csv")

# %%
df
# Out:
#          ID Region of residence  Age of Subject  Time spent on Online Class  \
# 0        R1           Delhi-NCR              21                         2.0
# 1        R2           Delhi-NCR              21                         0.0
# 2        R3           Delhi-NCR              20                         7.0
# 3        R4           Delhi-NCR              20                         3.0
# 4        R5           Delhi-NCR              21                         3.0
# ...     ...                 ...             ...                         ...
# 1177  R1191           Delhi-NCR              12                         3.0
# 1178  R1192           Delhi-NCR              14                         6.0
# 1179  R1193           Delhi-NCR              13                         4.0
# 1180  R1194           Delhi-NCR              14                         5.0
# 1181  R1195           Delhi-NCR              13                         5.0
#
# ...

# %% [markdown]
# ## ¿Cual es la frecuencia de edad dentro los participantes que contestaron la encuesta? ##

# %%
sns.distplot(df["Age of Subject"], 
             kde = False).set_title("Histogram of Age")
# Out:
# Text(0.5, 1.0, 'Histogram of Age')

# %% [markdown]
# ## ¿Como se representa y como estan distribuidas las horas en clases online de los participantes? ##

# %%
type("Prefered social media platform")
# Out:
# str

# %%
sns.boxplot("Age of Subject")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_68/2848830427.py in <module>
# ----> 1 sns.boxplot("Age of Subject")
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2233     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2234                           orient, color, palette, saturation,
# -> 2235                           width, dodge, fliersize, linewidth)
#    2236
#    2237     if ax is None:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     434                  width, dodge, fliersize, linewidth):
#     435
# ...
